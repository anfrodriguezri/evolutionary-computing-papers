# %%
from os import path, makedirs
from pickle import dump, load
from enum import Enum

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from Utils.haea import HAEA
from Utils.constants import PROPORTIONAL_SELECTION, RANK_SELECTION, TOURNAMENT_SELECTION, ELITIST_SELECTION, RANDOM_SELECTION

# %% [markdown]
# # Utils

# %% [markdown]
# ## Constants

# %%
ITERATIONS = 100
CHROMOSOME_LENGTH = 100
DIMENSIONS_LENGTH = 1
POPULATION_LENGTH = 100
GENERATIONS = 200
LIMITS = [0, 1]
POINTS = 400

# %%
class AssetType(Enum):
    graphic = 1
    data = 2

# %% [markdown]
# ## Functions

# %%
def save( type, folder, name, data = None ):
    if type == AssetType.graphic:
        filePath = f"Multimodal_Assets/Graphics/{folder}/{name}.png"
    else: ### AssetType.data
        filePath = f"Multimodal_Assets/Data/{name}.pickle"
    if not path.exists( path.dirname( filePath ) ):
        makedirs( path.dirname( filePath ) )
    if type == AssetType.graphic:
        plt.savefig( filePath )
    else: ### AssetType.data
        dump( data, open( filePath, "wb" ) )

# %%
def get( name ):
    filePath = f"Multimodal_Assets/Data/{name}.pickle"

    return load( open( filePath, "rb" ) )

# %%
def plot( x, y, isPoints, closes, title = None, folder = None, name = None ):
    if title:
        plt.title( title )
    if isPoints:
        plt.plot( x, y, "." )
    else:
        plt.plot( x, y )
    if closes:
        if folder and name:
            save( AssetType.graphic, folder, name )
        plt.show()
        plt.close()

# %%
def m1( x ):
    return np.sin( 5 * np.pi * x ) ** 6

# %%
def m2( x ):
    v = m1( x )
    y = ( x - 0.1 ) / 0.8

    return np.exp( -2.0 * 0.69314718 * y ** 2 ) * v

# %%
def m3( x ):
    x = x ** 0.75 - 0.05
    
    return m1( x )

# %%
def m4( x ):
    v = m3( x )
    y = ( x - 0.08 ) / 0.854
    
    return np.exp( -2.0 * 0.69314718 * y ** 2 ) * v

# %% [markdown]
# # Deterministic Crowding HAEA (DC-HAEA)

# %% [markdown]
# ## Real

# %%
def realDCHAEASteps( function, limits, functionName ):
    x = np.linspace( limits[0], limits[1], POINTS )
    y = function( x )
    
    realDCHAEA = HAEA( function, DIMENSIONS_LENGTH, POPULATION_LENGTH, limits )
    x0, x40, x80, x120, x160, x200 = realDCHAEA.realDCInit( GENERATIONS, RANK_SELECTION )
    
    plot( x, y, False, False, "Initial population" )
    plot( [i.chromosome for i in x0], [function( i.chromosome ) for i in x0], True, True, None, "DC-HAEA", f"real{functionName}x0" )
    
    plot( x, y, False, False, "After 40 generations" )
    plot( [i.chromosome for i in x40], [function( i.chromosome ) for i in x40], True, True, None, "DC-HAEA", f"real{functionName}x40" )
    
    plot( x, y, False, False, "After 80 generations" )
    plot( [i.chromosome for i in x80], [function( i.chromosome ) for i in x80], True, True, None, "DC-HAEA", f"real{functionName}x80" )
    
    plot( x, y, False, False, "After 120 generations" )
    plot( [i.chromosome for i in x120], [function( i.chromosome ) for i in x120], True, True, None, "DC-HAEA", f"real{functionName}x120" )
    
    plot( x, y, False, False, "After 160 generations" )
    plot( [i.chromosome for i in x160], [function( i.chromosome ) for i in x160], True, True, None, "DC-HAEA", f"real{functionName}x160" )
    
    plot( x, y, False, False, "After 200 generations" )
    plot( [i.chromosome for i in x200], [function( i.chromosome ) for i in x200], True, True, None, "DC-HAEA", f"real{functionName}x200" )

# %% [markdown]
# ### M1

# %%
realDCHAEASteps( m1, LIMITS, "M1" )

# %% [markdown]
# ### M2

# %%
realDCHAEASteps( m2, LIMITS, "M2" )

# %% [markdown]
# ### M3

# %%
realDCHAEASteps( m3, LIMITS, "M3" )

# %% [markdown]
# ### M4

# %%
realDCHAEASteps( m4, LIMITS, "M4" )

# %% [markdown]
# # Deterministic Crowding HAEA R (DC-HAEA-R)

# %% [markdown]
# ## Real

# %%
def realDCHAEARSteps( function, limits, functionName ):
    x = np.linspace( limits[0], limits[1], POINTS )
    y = function( x )
    
    realDCHAEAR = HAEA( function, DIMENSIONS_LENGTH, POPULATION_LENGTH, limits )
    x0, x40, x80, x120, x160, x200 = realDCHAEAR.realDCInit( GENERATIONS, RANK_SELECTION, "R" )
    
    plot( x, y, False, False, "Initial population" )
    plot( [i.chromosome for i in x0], [function( i.chromosome ) for i in x0], True, True, None, "DC-HAEA-R", f"real{functionName}x0" )
    
    plot( x, y, False, False, "After 40 generations" )
    plot( [i.chromosome for i in x40], [function( i.chromosome ) for i in x40], True, True, None, "DC-HAEA-R", f"real{functionName}x40" )
    
    plot( x, y, False, False, "After 80 generations" )
    plot( [i.chromosome for i in x80], [function( i.chromosome ) for i in x80], True, True, None, "DC-HAEA-R", f"real{functionName}x80" )
    
    plot( x, y, False, False, "After 120 generations" )
    plot( [i.chromosome for i in x120], [function( i.chromosome ) for i in x120], True, True, None, "DC-HAEA-R", f"real{functionName}x120" )
    
    plot( x, y, False, False, "After 160 generations" )
    plot( [i.chromosome for i in x160], [function( i.chromosome ) for i in x160], True, True, None, "DC-HAEA-R", f"real{functionName}x160" )
    
    plot( x, y, False, False, "After 200 generations" )
    plot( [i.chromosome for i in x200], [function( i.chromosome ) for i in x200], True, True, None, "DC-HAEA-R", f"real{functionName}x200" )

# %% [markdown]
# ### M1

# %%
realDCHAEARSteps( m1, LIMITS, "M1" )

# %% [markdown]
# ### M2

# %%
realDCHAEARSteps( m2, LIMITS, "M2" )

# %% [markdown]
# ### M3

# %%
realDCHAEARSteps( m3, LIMITS, "M3" )

# %% [markdown]
# ### M4

# %%
realDCHAEARSteps( m4, LIMITS, "M4" )

# %% [markdown]
# # Deterministic Crowding HAEA M (DC-HAEA-M)

# %% [markdown]
# ## Real

# %%
def realDCHAEAMSteps( function, limits, functionName ):
    x = np.linspace( limits[0], limits[1], POINTS )
    y = function( x )
    
    realDCHAEAR = HAEA( function, DIMENSIONS_LENGTH, POPULATION_LENGTH, limits )
    x0, x40, x80, x120, x160, x200 = realDCHAEAR.realDCInit( GENERATIONS, RANK_SELECTION, "M" )
    
    plot( x, y, False, False, "Initial population" )
    plot( [i.chromosome for i in x0], [function( i.chromosome ) for i in x0], True, True, None, "DC-HAEA-M", f"real{functionName}x0" )
    
    plot( x, y, False, False, "After 40 generations" )
    plot( [i.chromosome for i in x40], [function( i.chromosome ) for i in x40], True, True, None, "DC-HAEA-M", f"real{functionName}x40" )
    
    plot( x, y, False, False, "After 80 generations" )
    plot( [i.chromosome for i in x80], [function( i.chromosome ) for i in x80], True, True, None, "DC-HAEA-M", f"real{functionName}x80" )
    
    plot( x, y, False, False, "After 120 generations" )
    plot( [i.chromosome for i in x120], [function( i.chromosome ) for i in x120], True, True, None, "DC-HAEA-M", f"real{functionName}x120" )
    
    plot( x, y, False, False, "After 160 generations" )
    plot( [i.chromosome for i in x160], [function( i.chromosome ) for i in x160], True, True, None, "DC-HAEA-M", f"real{functionName}x160" )
    
    plot( x, y, False, False, "After 200 generations" )
    plot( [i.chromosome for i in x200], [function( i.chromosome ) for i in x200], True, True, None, "DC-HAEA-M", f"real{functionName}x200" )

# %% [markdown]
# ### M1

# %%
realDCHAEAMSteps( m1, LIMITS, "M1" )

# %% [markdown]
# ### M2

# %%
realDCHAEAMSteps( m2, LIMITS, "M2" )

# %% [markdown]
# ### M3

# %%
realDCHAEAMSteps( m3, LIMITS, "M3" )

# %% [markdown]
# ### M4

# %%
realDCHAEAMSteps( m4, LIMITS, "M4" )
